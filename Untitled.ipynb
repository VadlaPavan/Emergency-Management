# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as pp
import seaborn as sns
import sklearn 

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/lahar/Documents/Assignments/Bushfire prediction/RoadAccidents.csv")

# %%
import matplotlib.pyplot as plt

# %%
# Basic plot to display the distortion in the data 
df.hist(bins=50, figsize=(12,10))
plt.show()

# %%
a=df['Crash_Time'].value_counts()
b=df['Crash_Type'].value_counts()
df3= pd.DataFrame({'Crash_Time': a,
                   'Crash_Type': b})
df3.plot.bar(figsize=(20,5))

# %%
df_ru=df['Road_User'].value_counts()
df_ru
# Out:
# DRIVER          53001
# PASSENGER       22543
# MOTORCYCLIST    18474
# PEDESTRIAN      12544
# BICYCLIST        6276
# UNKNOWN          2705
# Name: Road_User, dtype: int64

# %%
df_ru.plot.bar()

# %%
df_ct=df['Crash_Time'].value_counts()
df_ct
# Out:
# 12:00 to 17:59    45709
# 06:00 to 11:59    30029
# 18:00 to 23:59    25937
# 00:00 to 05:59     9383
# UNKNOWN            4485
# Name: Crash_Time, dtype: int64

# %%
df_ct.plot.bar()

# %%
df_lga=df['Crash_LGA'].value_counts().head(10)
df_lga
# Out:
# GREATER GEELONG         4778
# CASEY                   4651
# MELBOURNE               4580
# GREATER DANDENONG       4032
# YARRA RANGES            3740
# MONASH                  3730
# UNKNOWN                 3473
# HUME                    3287
# MORNINGTON PENINSULA    3280
# BRIMBANK                2870
# Name: Crash_LGA, dtype: int64

# %%
df_lga.plot.bar(figsize=(20,5))
